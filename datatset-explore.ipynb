# %%
import os
import warnings
import pandas as pd
import numpy as np

warnings.filterwarnings("ignore")

# %%
# Specify the directory path
folder_dir = 'SWAN-SF dataset/partition2/FL'

# List all files in the specified directory
files = os.listdir(folder_dir)

# Print the number of files in the directory
print(len(files))
# Out:
# 1401

# %%
# Initialize empty DataFrames and counters
df_M = pd.DataFrame()
df_X = pd.DataFrame()
m_count = 0
x_count = 0

# Lists to store DataFrames for 'M' and 'X' files
df_M_list = []
df_X_list = []

# Iterate through files, read CSV, and categorize into 'M' or 'X'
for file in files:
    df_tmp = pd.read_csv(folder_dir + "/" + file, sep='\\t')
    if file[0] == 'M':
        m_count += 1
        df_M_list.append(df_tmp)
    elif file[0] == 'X':
        x_count += 1
        df_X_list.append(df_tmp)

# Concatenate DataFrames, reset index, and add labels
df_M = pd.concat(df_M_list, axis=0).reset_index(drop=True)
df_M['label'] = ['M'] * len(df_M)
df_X = pd.concat(df_X_list, axis=0).reset_index(drop=True)
df_X['label'] = ['X'] * len(df_X)

# Concatenate 'M' and 'X' DataFrames into a single DataFrame
df_all = pd.concat([df_M, df_X], axis=0).reset_index(drop=True)

# Print shapes and display the head of the combined DataFrame
print(df_M.shape)
print(df_X.shape)
print(df_all.shape)
df_all.head()
# Out:
# (79740, 56)
# (4320, 56)
# (84060, 56)
#              Timestamp      TOTUSJH        TOTBSQ        TOTPOT       TOTUSJZ  \
# 0  2012-05-08 22:00:00  5146.472386  7.581127e+10  1.549587e+24  8.780710e+13
# 1  2012-05-08 22:12:00  5127.598005  7.584110e+10  1.552657e+24  8.747561e+13
# 2  2012-05-08 22:24:00  5113.855462  7.579946e+10  1.548718e+24  8.675166e+13
# 3  2012-05-08 22:36:00  5121.940151  7.604100e+10  1.554365e+24  8.643489e+13
# 4  2012-05-08 22:48:00  5108.855689  7.600073e+10  1.555752e+24  8.627032e+13
#
#        ABSNJZH       SAVNCPP        USFLUX         TOTFZ       MEANPOT  ...  \
# 0  1332.547414  5.609936e+13  5.730030e+22 -1.207744e+25  14852.579455  ...
# 1  1408.543077  6.408036e+13  5.714176e+22 -1.202948e+25  14985.768247  ...
# 2  1413.928548  6.408015e+13  5.687938e+22 -1.213981e+25  15073.925695  ...
# 3  1416.740520  6.169980e+13  5.697616e+22 -1.211640e+25  15129.279469  ...
# 4  1356.798427  5.409737e+13  5.660194e+22 -1.198470e+25  15264.527464  ...
#
#    CFLARE_LOC  CFLARE_LABEL_LOC  MFLARE_LOC  MFLARE_LABEL_LOC  XFLARE_LOC  \
# 0         0.0               NaN         0.0               NaN         0.0
# 1         0.0               NaN         0.0               NaN         0.0
# 2         0.0               NaN         0.0               NaN         0.0
# 3         0.0               NaN         0.0               NaN         0.0
# 4         0.0               NaN         0.0               NaN         0.0
#
#    XFLARE_LABEL_LOC        XR_MAX  XR_QUAL  IS_TMFI  label
# 0               NaN  3.103700e-07       12     True      M
# 1               NaN  3.445700e-07       12     True      M
# 2               NaN  3.141900e-07       12     True      M
# 3               NaN  4.457000e-07       12     True      M
# 4               NaN  4.222700e-07        8     True      M
#
# [5 rows x 56 columns]

# %%
df_all.describe()
# Out:
#             TOTUSJH        TOTBSQ        TOTPOT       TOTUSJZ       ABSNJZH  \
# count  83823.000000  8.382300e+04  8.382300e+04  8.382300e+04  83823.000000
#            TOTUSJZ      ABSNJZH       SAVNCPP        USFLUX         TOTFZ  \
# 0     9.929197e+13  1042.555750  3.740947e+13  5.324630e+22 -1.422278e+25
# 1     1.001586e+14  1033.598153  3.645886e+13  5.329174e+22 -1.437758e+25
# 2     1.001534e+14  1018.473274  3.355922e+13  5.325693e+22 -1.421595e+25
# 3     9.965875e+13  1050.340406  3.693650e+13  5.318744e+22 -1.430105e+25
# 4     1.001185e+14  1066.843664  3.636122e+13  5.358100e+22 -1.453664e+25
# ...            ...          ...           ...           ...           ...
# 4315  1.375207e+14  1213.230914  6.352338e+13  8.517162e+22 -1.464681e+25
# 4316  1.383431e+14  1198.449631  6.285544e+13  8.539058e+22 -1.489523e+25
# 4317  1.370568e+14  1166.099998  5.786862e+13  8.509305e+22 -1.478516e+25
# 4318  1.373321e+14  1175.055198  6.010278e+13  8.523188e+22 -1.518746e+25
# 4319  1.367438e+14  1178.545349  5.835271e+13  8.515476e+22 -1.531688e+25
#
#            MEANPOT  ...  CFLARE_LOC   CFLARE_LABEL_LOC  MFLARE_LOC  \
# 0     13828.458802  ...         0.0                NaN         0.0
# 1     14019.859168  ...         0.0                NaN         0.0
# 2     13966.126792  ...         0.0                NaN         0.0
# 3     14055.382122  ...         0.0                NaN         0.0
# 4     14005.923742  ...         1.0  C6.2@4182:Primary         0.0
# ...            ...  ...         ...                ...         ...
# 4315  12468.333297  ...         0.0                NaN         0.0
# 4316  12369.794970  ...         0.0                NaN         0.0
# 4317  12408.533832  ...         0.0                NaN         0.0
# 4318  12371.224284  ...         0.0                NaN         0.0
# 4319  12343.407927  ...         0.0                NaN         0.0
#
#       MFLARE_LABEL_LOC  XFLARE_LOC  XFLARE_LABEL_LOC        XR_MAX  XR_QUAL  \
# 0                  NaN         0.0               NaN  5.115000e-06       12
# 1                  NaN         0.0               NaN  2.648600e-06       12
# 2                  NaN         0.0               NaN  2.820100e-06       12
# 3                  NaN         0.0               NaN  3.246100e-06       12
# 4                  NaN         0.0               NaN  2.382000e-06       12
# ...                ...         ...               ...           ...      ...
# 4315               NaN         0.0               NaN  7.704600e-07       12
# 4316               NaN         0.0               NaN  8.061700e-07       12
# 4317               NaN         0.0               NaN  8.663200e-07       12
# 4318               NaN         0.0               NaN  8.680400e-07       12
# 4319               NaN         0.0               NaN  9.129900e-07       12
#
#       IS_TMFI  label
# 0        True      X
# 1        True      X
# 2        True      X
# 3        True      X
# 4        True      X
# ...       ...    ...
# 4315     True      X
# 4316     True      X
# 4317     True      X
# 4318     True      X
# 4319     True      X
#
# [4320 rows x 56 columns]

# %% [markdown]
# # Mean value of TOTPOT feature for Label X

# %%
# Extract non-null values of 'TOTPOT' from DataFrame 'df_X'
totpot = df_X[df_X['TOTPOT'].notnull()]['TOTPOT']

# Print information about data points in class 'X' in partition2
print("Length of data points of class X in partition2:", len(df_X))
print("Count of NaN values in TOTPOT:", len(df_X) - len(totpot))

# After dropping NaN values, print mean and median of 'TOTPOT'
print("\nAfter dropping the NaN values - ")
print("Mean:", np.mean(totpot))
print("Median:", np.median(totpot))
# Out:
# Length of data points of class X in partition2: 4320
# Count of NaN values in TOTPOT: 24
#
# After dropping the NaN values -
# Mean : 1.6518857529269846e+24
# Median : 1.5439726726094336e+24
